# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('deeplearning.mplstyle')

x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])
print("x_tarin = ", x_train)
print("y_tarin = ", y_train)
# Out:
# x_tarin =  [1. 2.]
# y_tarin =  [300. 500.]

# %%
print("x_train.shape = ", x_train.shape)  # 因为是一纬数组，所以 输出 2 表示长度，如果是二维数组，例如输出（3，4），表示三行四列的矩阵
m = x_train.shape[0]
print("Number of training examples = ", m)  # 输出样本的数量
# Out:
# x_train.shape =  (2,)
# Number of training examples =  2

# %% [markdown]
# # 同样，也可以使用 len() 来找出样本的数量

# %%
m = len(x_train)
print("Number of training examples = ", m)
# Out:
# Number of training examples =  2

# %%
i = 0
x_i = x_train[i]
y_i = y_train[i]
print("x^i = ", x_i, " y^i = ", y_i)
# Out:
# x^i =  1.0  y^i =  300.0

# %%
plt.scatter(x_train, y_train, marker='x', c='r')
plt.title("Housing Prices")
plt.ylabel("Price (in 1000s of dollars)")
plt.xlabel("Size (1000 sqft)")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
w = 100
b = 100


def compute_model_output(x, w, b):
    """
    Computes the prediction of a linear model
    Args:
      x (ndarray (m,)): Data, m examples 
      w,b (scalar)    : model parameters  
    Returns
      y (ndarray (m,)): target values
    """
    m = x.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w * x[i] + b
        
    return f_wb

# %%
w = 200
b = 100
tmp_f_wb = compute_model_output(x_train, w, b)
plt.plot(x_train, tmp_f_wb, c='b', label='Our Prediction')
plt.scatter(x_train, y_train, marker='x', c='r', label="Actual Values")
# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()
